# %%
pip install flask
# Out:
# Requirement already satisfied: flask in C:\Users\Lenovo\anaconda3\Lib\site-packages (3.1.3)
# Requirement already satisfied: blinker>=1.9.0 in C:\Users\Lenovo\anaconda3\Lib\site-packages (from flask) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in C:\Users\Lenovo\anaconda3\Lib\site-packages (from flask) (8.4.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in C:\Users\Lenovo\anaconda3\Lib\site-packages (from flask) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in C:\Users\Lenovo\anaconda3\Lib\site-packages (from flask) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in C:\Users\Lenovo\anaconda3\Lib\site-packages (from flask) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in C:\Users\Lenovo\anaconda3\Lib\site-packages (from flask) (3.1.6)
# Requirement already satisfied: colorama in C:\Users\Lenovo\anaconda3\Lib\site-packages (from click>=8.1.3->flask) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
print("======================================")
print("      INVENTORY MANAGEMENT SYSTEM")
print("======================================")
print("Project started successfully!")
# Out:
# ======================================
#       INVENTORY MANAGEMENT SYSTEM
# ======================================
# Project started successfully!

# %%
product_name = "Rice"
unit = "Kg"
quantity = 100
purchase_price = 90
selling_price = 110

# %%
print("Product:", product_name)
print("Unit:", unit)
print("Quantity:", quantity)
print("Purchase Price:", purchase_price)
print("Selling Price:", selling_price)
# Out:
# Product: Rice
# Unit: Kg
# Quantity: 100
# Purchase Price: 90
# Selling Price: 110

# %%
stock_value = quantity * purchase_price

print("Stock Value:", stock_value)
# Out:
# Stock Value: 9000

# %%
import sqlite3

conn = sqlite3.connect("inventory.db")
cursor = conn.cursor()

cursor.execute("""
CREATE TABLE IF NOT EXISTS products (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    product_code TEXT UNIQUE,
    product_name TEXT NOT NULL,
    category TEXT,
    unit TEXT NOT NULL,
    purchase_price REAL,
    selling_price REAL,
    stock REAL DEFAULT 0,
    minimum_stock REAL DEFAULT 0
)
""")

conn.commit()

print("Database created successfully!")
# Out:
# Database created successfully!

# %%
cursor.execute("""
INSERT INTO products
(product_code, product_name, category, unit, purchase_price, selling_price, stock, minimum_stock)
VALUES (?, ?, ?, ?, ?, ?, ?, ?)
""", ("P001", "Rice", "Grocery", "Kg", 90, 110, 100, 20))

conn.commit()

print("Product added successfully!")
# Out:
# Product added successfully!

# %%
cursor.execute("SELECT * FROM products")

products = cursor.fetchall()

for product in products:
    print(product)
# Out:
# (1, 'P001', 'Rice', 'Grocery', 'Kg', 90.0, 110.0, 100.0, 20.0)

# %%
def add_product():
    code = input("Product Code: ")
    name = input("Product Name: ")
    category = input("Category: ")
    unit = input("Unit (Piece/Kg/Gram/Liter/Box): ")
    purchase = float(input("Purchase Price: "))
    selling = float(input("Selling Price: "))
    stock = float(input("Opening Stock: "))
    minimum = float(input("Minimum Stock: "))

    try:
        cursor.execute("""
        INSERT INTO products
        (product_code, product_name, category, unit,
         purchase_price, selling_price, stock, minimum_stock)
        VALUES (?, ?, ?, ?, ?, ?, ?, ?)
        """, (code, name, category, unit, purchase, selling, stock, minimum))

        conn.commit()
        print("Product added successfully!")

    except sqlite3.IntegrityError:
        print("Error: Product code already exists.")

# %%
add_product()
# Out:
# Product Code:  p002
# Product Name:  oil
# Category:  grocery
# Unit (Piece/Kg/Gram/Liter/Box):  liter
# Purchase Price:  350
# Selling Price:  380
# Opening Stock:  700
# Minimum Stock:  100
# Product added successfully!

# %%
def view_products():
    cursor.execute("SELECT * FROM products")
    products = cursor.fetchall()

    for product in products:
        print(product)
view_products()
# Out:
# (1, 'P001', 'Rice', 'Grocery', 'Kg', 90.0, 110.0, 100.0, 20.0)
# (2, 'p002', 'oil', 'grocery', 'liter', 350.0, 380.0, 700.0, 100.0)

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS transactions (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    product_code TEXT,
    transaction_type TEXT,
    quantity REAL,
    date TEXT
)
""")

conn.commit()

print("Transaction table created!")
# Out:
# Transaction table created!

# %%
def stock_in():
    code = input("Product Code: ")
    qty = float(input("Quantity received: "))

    cursor.execute(
        "UPDATE products SET stock = stock + ? WHERE product_code = ?",
        (qty, code)
    )

    cursor.execute("""
        INSERT INTO transactions
        (product_code, transaction_type, quantity, date)
        VALUES (?, 'IN', ?, datetime('now'))
    """, (code, qty))

    conn.commit()
    print("Stock added successfully!")
stock_in()
# Out:
# Product Code:  p002
# Quantity received:  100
# Stock added successfully!

# %%
def stock_out():
    code = input("Product Code: ")
    qty = float(input("Quantity issued/sold: "))

    cursor.execute(
        "SELECT stock FROM products WHERE product_code = ?",
        (code,)
    )

    result = cursor.fetchone()

    if result is None:
        print("Product not found!")
        return

    if qty > result[0]:
        print("Insufficient stock!")
        return

    cursor.execute(
        "UPDATE products SET stock = stock - ? WHERE product_code = ?",
        (qty, code)
    )

    cursor.execute("""
        INSERT INTO transactions
        (product_code, transaction_type, quantity, date)
        VALUES (?, 'OUT', ?, datetime('now'))
    """, (code, qty))

    conn.commit()
    print("Stock removed successfully!")
stock_out()
# Out:
# Product Code:  P001
# Quantity issued/sold:  10
# Stock removed successfully!

# %%
view_products()
# Out:
# (1, 'P001', 'Rice', 'Grocery', 'Kg', 90.0, 110.0, 90.0, 20.0)
# (2, 'p002', 'oil', 'grocery', 'liter', 350.0, 380.0, 800.0, 100.0)

# %%
import pandas as pd
def view_inventory():
    cursor.execute("""
        SELECT product_code, product_name, category, unit,
               purchase_price, selling_price, stock, minimum_stock
        FROM products
    """)

    data = cursor.fetchall()

    columns = [
        "Code", "Product", "Category", "Unit",
        "Purchase Price", "Selling Price",
        "Stock", "Minimum Stock"
    ]

    df = pd.DataFrame(data, columns=columns)
    display(df)
view_inventory()
# Out:
#    Code Product Category   Unit  Purchase Price  Selling Price  Stock  \
# 0  P001    Rice  Grocery     Kg            90.0          110.0   90.0
# 1  p002     oil  grocery  liter           350.0          380.0  800.0
#
#    Minimum Stock
# 0           20.0
# 1          100.0

# %%
def low_stock():
    cursor.execute("""
        SELECT product_code, product_name, unit, stock, minimum_stock
        FROM products
        WHERE stock <= minimum_stock
    """)

    data = cursor.fetchall()

    df = pd.DataFrame(
        data,
        columns=["Code", "Product", "Unit", "Stock", "Minimum Stock"]
    )

    display(df)
low_stock()
# Out:
# Empty DataFrame
# Columns: [Code, Product, Unit, Stock, Minimum Stock]
# Index: []

# %%
def search_product():
    name = input("Enter product name: ")

    cursor.execute("""
        SELECT * FROM products
        WHERE product_name LIKE ?
    """, ('%' + name + '%',))

    data = cursor.fetchall()

    for product in data:
        print(product)
search_product()
# Out:
# Enter product name:  oil
# (2, 'p002', 'oil', 'grocery', 'liter', 350.0, 380.0, 800.0, 100.0)

# %%
def main_menu():
    while True:
        print("\n==============================")
        print(" INVENTORY MANAGEMENT SYSTEM")
        print("==============================")
        print("1. Add Product")
        print("2. View Inventory")
        print("3. Stock In")
        print("4. Stock Out")
        print("5. Search Product")
        print("6. Low Stock")
        print("7. Exit")
        print("==============================")

        choice = input("Enter your choice: ")

        if choice == "1":
            add_product()

        elif choice == "2":
            view_inventory()

        elif choice == "3":
            stock_in()

        elif choice == "4":
            stock_out()

        elif choice == "5":
            search_product()

        elif choice == "6":
            low_stock()

        elif choice == "7":
            print("Thank you for using the system!")
            break

        else:
            print("Invalid choice. Please try again.")
main_menu()
# Out:
# ==============================
#  INVENTORY MANAGEMENT SYSTEM
# ==============================
# 1. Add Product
# 2. View Inventory
# 3. Stock In
# 4. Stock Out
# 5. Search Product
# 6. Low Stock
# 7. Exit
# ==============================
# Enter your choice:  1
# Product Code:  p003
# Product Name:  soap
# Category:  hygine
# Unit (Piece/Kg/Gram/Liter/Box):  piece
# Purchase Price:  25
# Selling Price:  35
# Opening Stock:  500
# Minimum Stock:  50
# Product added successfully!
#
# ==============================
#  INVENTORY MANAGEMENT SYSTEM
# ==============================
# 1. Add Product
# 2. View Inventory
# 3. Stock In
# 4. Stock Out
# 5. Search Product
# 6. Low Stock
# 7. Exit
# ==============================
# Enter your choice:  1
# Product Code:  p004
# Product Name:  noodles
# Category:  fastfood
# Unit (Piece/Kg/Gram/Liter/Box):  box
# Purchase Price:  240
# Selling Price:  280
# Opening Stock:  1000
# Minimum Stock:  100
# Product added successfully!
#
# ==============================
#  INVENTORY MANAGEMENT SYSTEM
# ==============================
# 1. Add Product
# 2. View Inventory
# 3. Stock In
# 4. Stock Out
# 5. Search Product
# 6. Low Stock
# 7. Exit
# ==============================
# Enter your choice:  7
# Thank you for using the system!

# %%
def export_to_excel():
    cursor.execute("""
        SELECT product_code, product_name, category, unit,
               purchase_price, selling_price, stock, minimum_stock
        FROM products
    """)

    data = cursor.fetchall()

    columns = [
        "Code", "Product", "Category", "Unit",
        "Purchase Price", "Selling Price",
        "Stock", "Minimum Stock"
    ]

    df = pd.DataFrame(data, columns=columns)

    df.to_excel("inventory_report.xlsx", index=False)

    print("Inventory exported to Excel successfully!")
export_to_excel()
# Out:
# Inventory exported to Excel successfully!

# %%
def main_menu():
    while True:
        print("\n==============================")
        print(" INVENTORY MANAGEMENT SYSTEM")
        print("==============================")
        print("1. Add Product")
        print("2. View Inventory")
        print("3. Stock In")
        print("4. Stock Out")
        print("5. Search Product")
        print("6. Low Stock")
        print("7. Export to Excel")
        print("8. Exit")
        print("==============================")

        choice = input("Enter your choice: ")

        if choice == "1":
            add_product()
        elif choice == "2":
            view_inventory()
        elif choice == "3":
            stock_in()
        elif choice == "4":
            stock_out()
        elif choice == "5":
            search_product()
        elif choice == "6":
            low_stock()
        elif choice == "7":
            export_to_excel()
        elif choice == "8":
            print("Thank you for using the system!")
            break
        else:
            print("Invalid choice.")
main_menu()
# Out:
# ==============================
#  INVENTORY MANAGEMENT SYSTEM
# ==============================
# 1. Add Product
# 2. View Inventory
# 3. Stock In
# 4. Stock Out
# 5. Search Product
# 6. Low Stock
# 7. Export to Excel
# 8. Exit
# ==============================
# Enter your choice:  1
# Product Code:  p005
# Product Name:  toothpaste
# Category:  hygine
# Unit (Piece/Kg/Gram/Liter/Box):  piece
# Purchase Price:  60
# Selling Price:  804
# Opening Stock:  600
# Minimum Stock:  10
# Product added successfully!
#
# ==============================
#  INVENTORY MANAGEMENT SYSTEM
# ==============================
# 1. Add Product
# 2. View Inventory
# 3. Stock In
# 4. Stock Out
# 5. Search Product
# 6. Low Stock
# 7. Export to Excel
# 8. Exit
# ==============================
# Enter your choice:  8
# Thank you for using the system!

# %%
cursor.execute("DROP TABLE IF EXISTS transactions")

cursor.execute("""
CREATE TABLE transactions (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    product_code TEXT,
    transaction_type TEXT,
    quantity REAL,
    unit_price REAL,
    party TEXT,
    remarks TEXT,
    date TEXT
)
""")

conn.commit()

print("Transaction table updated!")
# Out:
# Transaction table updated!

# %%
def stock_in():
    code = input("Product Code: ")
    qty = float(input("Quantity received: "))
    price = float(input("Purchase Price: "))
    party = input("Supplier: ")
    remarks = input("Remarks: ")

    cursor.execute(
        "SELECT stock FROM products WHERE product_code = ?",
        (code,)
    )

    if cursor.fetchone() is None:
        print("Product not found!")
        return

    cursor.execute(
        "UPDATE products SET stock = stock + ? WHERE product_code = ?",
        (qty, code)
    )

    cursor.execute("""
        INSERT INTO transactions
        (product_code, transaction_type, quantity,
         unit_price, party, remarks, date)
        VALUES (?, 'IN', ?, ?, ?, ?, datetime('now'))
    """, (code, qty, price, party, remarks))

    conn.commit()

    print("Stock received successfully!")
def stock_out():
    code = input("Product Code: ")
    qty = float(input("Quantity issued/sold: "))
    price = float(input("Selling Price: "))
    party = input("Customer: ")
    remarks = input("Remarks: ")

    cursor.execute(
        "SELECT stock FROM products WHERE product_code = ?",
        (code,)
    )

    result = cursor.fetchone()

    if result is None:
        print("Product not found!")
        return

    if qty > result[0]:
        print("Insufficient stock!")
        return

    cursor.execute(
        "UPDATE products SET stock = stock - ? WHERE product_code = ?",
        (qty, code)
    )

    cursor.execute("""
        INSERT INTO transactions
        (product_code, transaction_type, quantity,
         unit_price, party, remarks, date)
        VALUES (?, 'OUT', ?, ?, ?, ?, datetime('now'))
    """, (code, qty, price, party, remarks))

    conn.commit()

    print("Stock issued successfully!")
def transaction_history():
    cursor.execute("""
        SELECT id, product_code, transaction_type,
               quantity, unit_price, party, remarks, date
        FROM transactions
        ORDER BY id DESC
    """)

    data = cursor.fetchall()

    columns = [
        "ID", "Code", "Type", "Quantity",
        "Unit Price", "Party", "Remarks", "Date"
    ]

    df = pd.DataFrame(data, columns=columns)
    display(df)
transaction_history()
# Out:
# Empty DataFrame
# Columns: [ID, Code, Type, Quantity, Unit Price, Party, Remarks, Date]
# Index: []

# %%
def dashboard():
    # Total products
    cursor.execute("SELECT COUNT(*) FROM products")
    total_products = cursor.fetchone()[0]

    # Total stock
    cursor.execute("SELECT SUM(stock) FROM products")
    total_stock = cursor.fetchone()[0] or 0

    # Total stock value
    cursor.execute("""
        SELECT SUM(stock * purchase_price)
        FROM products
    """)
    stock_value = cursor.fetchone()[0] or 0

    # Low stock count
    cursor.execute("""
        SELECT COUNT(*)
        FROM products
        WHERE stock <= minimum_stock
    """)
    low_stock_count = cursor.fetchone()[0]

    print("\n===================================")
    print("        INVENTORY DASHBOARD")
    print("===================================")
    print(f"Total Products   : {total_products}")
    print(f"Total Stock      : {total_stock}")
    print(f"Stock Value      : Rs. {stock_value:,.2f}")
    print(f"Low Stock Items  : {low_stock_count}")
    print("===================================")
dashboard()
# Out:
# ===================================
#         INVENTORY DASHBOARD
# ===================================
# Total Products   : 5
# Total Stock      : 2990.0
# Stock Value      : Rs. 576,600.00
# Low Stock Items  : 0
# ===================================

# %%
def main_menu():
    while True:
        print("\n==============================")
        print(" INVENTORY MANAGEMENT SYSTEM")
        print("==============================")
        print("1. Dashboard")
        print("2. Add Product")
        print("3. View Inventory")
        print("4. Stock In")
        print("5. Stock Out")
        print("6. Search Product")
        print("7. Low Stock")
        print("8. Transaction History")
        print("9. Export to Excel")
        print("10. Exit")
        print("==============================")

        choice = input("Enter your choice: ")

        if choice == "1":
            dashboard()
        elif choice == "2":
            add_product()
        elif choice == "3":
            view_inventory()
        elif choice == "4":
            stock_in()
        elif choice == "5":
            stock_out()
        elif choice == "6":
            search_product()
        elif choice == "7":
            low_stock()
        elif choice == "8":
            transaction_history()
        elif choice == "9":
            export_to_excel()
        elif choice == "10":
            print("Thank you for using the system!")
            break
        else:
            print("Invalid choice.")
main_menu()
# Out:
# ==============================
#  INVENTORY MANAGEMENT SYSTEM
# ==============================
# 1. Dashboard
# 2. Add Product
# 3. View Inventory
# 4. Stock In
# 5. Stock Out
# 6. Search Product
# 7. Low Stock
# 8. Transaction History
# 9. Export to Excel
# 10. Exit
# ==============================
# Enter your choice:  1
# ===================================
#         INVENTORY DASHBOARD
# ===================================
# Total Products   : 5
# Total Stock      : 2990.0
# Stock Value      : Rs. 576,600.00
# Low Stock Items  : 0
# ===================================
#
# ==============================
#  INVENTORY MANAGEMENT SYSTEM
# ==============================
# 1. Dashboard
# 2. Add Product
# 3. View Inventory
# 4. Stock In
# 5. Stock Out
# 6. Search Product
# 7. Low Stock
# 8. Transaction History
# 9. Export to Excel
# 10. Exit
# ==============================
# Enter your choice:  4
# Product Code:  p002
# Quantity received:  400
# Purchase Price:  180
# Supplier:  kisan
# Remarks:  price may up and down
# Stock received successfully!
#
# ==============================
#  INVENTORY MANAGEMENT SYSTEM
# ==============================
# 1. Dashboard
# 2. Add Product
# 3. View Inventory
# 4. Stock In
# 5. Stock Out
# 6. Search Product
# 7. Low Stock
# 8. Transaction History
# 9. Export to Excel
# 10. Exit
# ==============================
# Enter your choice:  10
# Thank you for using the system!

# %%
def edit_product():
    code = input("Enter Product Code: ")

    cursor.execute(
        "SELECT * FROM products WHERE product_code = ?",
        (code,)
    )

    product = cursor.fetchone()

    if product is None:
        print("Product not found!")
        return

    print("Leave blank to keep the existing value.")

    name = input(f"Product Name [{product[2]}]: ") or product[2]
    category = input(f"Category [{product[3]}]: ") or product[3]
    unit = input(f"Unit [{product[4]}]: ") or product[4]

    purchase = input(f"Purchase Price [{product[5]}]: ")
    selling = input(f"Selling Price [{product[6]}]: ")
    minimum = input(f"Minimum Stock [{product[8]}]: ")

    purchase = float(purchase) if purchase else product[5]
    selling = float(selling) if selling else product[6]
    minimum = float(minimum) if minimum else product[8]

    cursor.execute("""
        UPDATE products
        SET product_name = ?,
            category = ?,
            unit = ?,
            purchase_price = ?,
            selling_price = ?,
            minimum_stock = ?
        WHERE product_code = ?
    """, (
        name, category, unit,
        purchase, selling, minimum, code
    ))

    conn.commit()

    print("Product updated successfully!")
edit_product()
# Out:
# Enter Product Code:  P001
# Leave blank to keep the existing value.
# Product Name [Rice]:  maize
# Category [Grocery]:  grocery
# Unit [Kg]:
# Purchase Price [90.0]:
# Selling Price [110.0]:
# Minimum Stock [20.0]:
# Product updated successfully!

# %%
def delete_product():
    code = input("Enter Product Code to delete: ")

    cursor.execute(
        "SELECT product_name FROM products WHERE product_code = ?",
        (code,)
    )

    product = cursor.fetchone()

    if product is None:
        print("Product not found!")
        return

    confirm = input(
        f"Delete {product[0]}? (yes/no): "
    ).lower()

    if confirm == "yes":
        cursor.execute(
            "DELETE FROM products WHERE product_code = ?",
            (code,)
        )

        conn.commit()

        print("Product deleted successfully!")
    else:
        print("Delete cancelled.")
print("1. Dashboard")
print("2. Add Product")
print("3. View Inventory")
print("4. Edit Product")
print("5. Delete Product")
print("6. Stock In")
print("7. Stock Out")
print("8. Search Product")
print("9. Low Stock")
print("10. Transaction History")
print("11. Export to Excel")
print("12. Exit")
# Out:
# 1. Dashboard
# 2. Add Product
# 3. View Inventory
# 4. Edit Product
# 5. Delete Product
# 6. Stock In
# 7. Stock Out
# 8. Search Product
# 9. Low Stock
# 10. Transaction History
# 11. Export to Excel
# 12. Exit

# %%
main_menu()
# Out:
# ==============================
#  INVENTORY MANAGEMENT SYSTEM
# ==============================
# 1. Dashboard
# 2. Add Product
# 3. View Inventory
# 4. Stock In
# 5. Stock Out
# 6. Search Product
# 7. Low Stock
# 8. Transaction History
# 9. Export to Excel
# 10. Exit
# ==============================
# Enter your choice:  10
# Thank you for using the system!

# %%
view_inventory()
# Out:
#    Code     Product  Category   Unit  Purchase Price  Selling Price   Stock  \
# 0  P001       maize   grocery     Kg            90.0          110.0    90.0
# 1  p002         oil   grocery  liter           350.0          380.0  1200.0
# 2  p003        soap    hygine  piece            25.0           35.0   500.0
# 3  p004     noodles  fastfood    box           240.0          280.0  1000.0
# 4  p005  toothpaste    hygine  piece            60.0          804.0   600.0
#
#    Minimum Stock
# 0           20.0
# 1          100.0
# 2           50.0
# 3          100.0
# 4           10.0

# %%
low_stock()
# Out:
# Empty DataFrame
# Columns: [Code, Product, Unit, Stock, Minimum Stock]
# Index: []

# %%
def low_stock():
    cursor.execute("""
        SELECT product_code, product_name, unit, stock, minimum_stock
        FROM products
        WHERE stock <= minimum_stock
    """)

    data = cursor.fetchall()

    if not data:
        print("\n✓ No low-stock products.")
        return

    columns = ["Code", "Product", "Unit", "Stock", "Minimum Stock"]

    df = pd.DataFrame(data, columns=columns)

    print("\n⚠ LOW STOCK PRODUCTS")
    display(df)
low_stock()
# Out:
# ✓ No low-stock products.

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Lenovo\Desktop\python\inventory_system

# %%
git init
git add inventory_management.ipynb
git commit -m "Add inventory management notebook"
# Out:
#   Cell In[3], line 1
#     git init
#         ^
# SyntaxError: invalid syntax

# %%
cd "%USERPROFILE%\Desktop\python\inventory_system"
# Out:
# [WinError 3] The system cannot find the path specified: '%USERPROFILE%\\Desktop\\python\\inventory_system'
# C:\Users\Lenovo\Desktop\python\inventory_system
